# %% [markdown]
# <a href="https://colab.research.google.com/github/KasukurthiAbraham/KasukurthiAbraham/blob/main/Another_copy_of_Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
ds = pd.read_csv('/content/drive/MyDrive/Credit_Card_Applications (1).csv')

# %%
ds. head()
# Out:
#    CustomerID  A1     A2     A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  \
# 0    15776156   1  22.08  11.46   2   4   4  1.585   0   0    0    1    2
# 1    15739548   0  22.67   7.00   2   8   4  0.165   0   0    0    0    2
# 2    15662854   0  29.58   1.75   1   4   4  1.250   0   0    0    1    2
# 3    15687688   0  21.67  11.50   1   5   3  0.000   1   1   11    1    2
# 4    15715750   1  20.17   8.17   2   6   4  1.960   1   1   14    0    2
#
#    A13   A14  Class
# 0  100  1213      0
# 1  160     1      0
# 2  280     1      0
# 3    0     1      1
# 4   60   159      1

# %%
df1. head()
# Out:
#    Age  Height  Weight  Speed
# 0   39      28      52     20
# 1   33      36      77     36
# 2   67      87      19     47
# 3   81      83      35     63
# 4   65      10      75     94

# %%
ds
# Out:
#      CustomerID  A1     A2      A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  \
# 0      15776156   1  22.08  11.460   2   4   4  1.585   0   0    0    1    2
# 1      15739548   0  22.67   7.000   2   8   4  0.165   0   0    0    0    2
# 2      15662854   0  29.58   1.750   1   4   4  1.250   0   0    0    1    2
# 3      15687688   0  21.67  11.500   1   5   3  0.000   1   1   11    1    2
# 4      15715750   1  20.17   8.170   2   6   4  1.960   1   1   14    0    2
# ..          ...  ..    ...     ...  ..  ..  ..    ...  ..  ..  ...  ...  ...
# 685    15808223   1  31.57  10.500   2  14   4  6.500   1   0    0    0    2
# 686    15769980   1  20.67   0.415   2   8   4  0.125   0   0    0    0    2
# 687    15675450   0  18.83   9.540   2   6   4  0.085   1   0    0    0    2
# 688    15776494   0  27.42  14.500   2  14   8  3.085   1   1    1    0    2
# 689    15592412   1  41.00   0.040   2  10   4  0.040   0   1    1    0    1
#
#      A13   A14  Class
# ...

# %%
ds. head(10)
# Out:
#    CustomerID  A1     A2      A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  \
# 0    15776156   1  22.08  11.460   2   4   4  1.585   0   0    0    1    2
# 1    15739548   0  22.67   7.000   2   8   4  0.165   0   0    0    0    2
# 2    15662854   0  29.58   1.750   1   4   4  1.250   0   0    0    1    2
# 3    15687688   0  21.67  11.500   1   5   3  0.000   1   1   11    1    2
# 4    15715750   1  20.17   8.170   2   6   4  1.960   1   1   14    0    2
# 5    15571121   0  15.83   0.585   2   8   8  1.500   1   1    2    0    2
# 6    15726466   1  17.42   6.500   2   3   4  0.125   0   0    0    0    2
# 7    15660390   0  58.67   4.460   2  11   8  3.040   1   1    6    0    2
# 8    15663942   1  27.83   1.000   1   2   8  3.000   0   0    0    0    2
# 9    15638610   0  55.75   7.080   2   4   8  6.750   1   1    3    1    2
#
#    A13   A14  Class
# 0  100  1213      0
# 1  160     1      0
# 2  280     1      0
# 3    0     1      1
# 4   60   159      1
# ...

# %%
ds. tail()
# Out:
#      CustomerID  A1     A2      A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  \
# 685    15808223   1  31.57  10.500   2  14   4  6.500   1   0    0    0    2
# 686    15769980   1  20.67   0.415   2   8   4  0.125   0   0    0    0    2
# 687    15675450   0  18.83   9.540   2   6   4  0.085   1   0    0    0    2
# 688    15776494   0  27.42  14.500   2  14   8  3.085   1   1    1    0    2
# 689    15592412   1  41.00   0.040   2  10   4  0.040   0   1    1    0    1
#
#      A13  A14  Class
# 685    0    1      1
# 686    0   45      0
# 687  100    1      1
# 688  120   12      1
# 689  560    1      1

# %%
import random
age=[]
height=[]
weight=[]
speed=[]
for _ in range(100):
    age.append(random.randint(0, 100))
    height.append(random.randint(0,100))
    weight.append(random.randint(0,100))
    speed.append(random.randint(0,100))
idata={'Age':age, 'Height':height, 'Weight':weight, 'Speed':speed}


import pandas as pd
df1 = pd.DataFrame(idata)
print(df1)
# Out:
#     Age  Height  Weight  Speed
# 0    39      28      52     20
# 1    33      36      77     36
# 2    67      87      19     47
# 3    81      83      35     63
# 4    65      10      75     94
# ..  ...     ...     ...    ...
# 95   64      26      86     96
# 96   85      40      38      2
# 97   32      21      83      6
# 98   43      73      88     24
# 99   84      73      79     79
#
# [100 rows x 4 columns]

# %%
df1. head()
# Out:
#    Age  Height  Weight  Speed
# 0   39      28      52     20
# 1   33      36      77     36
# 2   67      87      19     47
# 3   81      83      35     63
# 4   65      10      75     94

# %%
df1. head(10)
# Out:
#    Age  Height  Weight  Speed
# 0   39      28      52     20
# 1   33      36      77     36
# 2   67      87      19     47
# 3   81      83      35     63
# 4   65      10      75     94
# 5   54      89       8     83
# 6   24      89      43     39
# 7   76      38     100     53
# 8   76       7      80     28
# 9   32      52      47     85

# %%
df1. tail(10)
# Out:
#     Age  Height  Weight  Speed
# 90   94      61      34     79
# 91   13      15      29     32
# 92   65      12      15     10
# 93   22      84      45      2
# 94   76      26      89     99
# 95   64      26      86     96
# 96   85      40      38      2
# 97   32      21      83      6
# 98   43      73      88     24
# 99   84      73      79     79

# %%
df1. describe()
# Out:
#               Age      Height      Weight       Speed
# count  100.000000  100.000000  100.000000  100.000000
# mean    52.370000   47.860000   53.710000   50.200000
# std     29.873016   27.776532   27.668417   28.363798
# min      2.000000    0.000000    3.000000    0.000000
# 25%     26.250000   22.750000   31.250000   28.000000
# 50%     57.000000   48.500000   56.500000   49.000000
# 75%     76.000000   72.250000   77.000000   77.250000
# max     99.000000   95.000000  100.000000   99.000000

# %%
df1["Age"]
# Out:
# 0     39
# 1     33
# 2     67
# 3     81
# 4     65
#       ..
# 95    64
# 96    85
# 97    32
# 98    43
# 99    84
# Name: Age, Length: 100, dtype: int64

# %%
df1["Weight"]
# Out:
# 0     52
# 1     77
# 2     19
# 3     35
# 4     75
#       ..
# 95    86
# 96    38
# 97    83
# 98    88
# 99    79
# Name: Weight, Length: 100, dtype: int64

# %%
df1["Height"]
# Out:
# 0     28
# 1     36
# 2     87
# 3     83
# 4     10
#       ..
# 95    26
# 96    40
# 97    21
# 98    73
# 99    73
# Name: Height, Length: 100, dtype: int64
